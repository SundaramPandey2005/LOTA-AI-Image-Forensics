# %% [markdown]
# # Notebook 03: Experimental Analysis & Grounded Intelligence Layer
# Explore benchmark heatmaps, ablation charts, and natural language SQL query synthesis.

# %%
import sys
import os
sys.path.insert(0, '..')

from src.intelligence.intent_router import route_and_execute_query
from src.intelligence.explanation import format_grounded_response

questions = [
    'Which generator is the hardest to detect?',
    'Did MGPS improve performance?',
    'Which model performs best on Midjourney?',
    'List all experiments'
]

for q in questions:
    print(f'User Query: "{q}"')
    res = route_and_execute_query(q, db_path='../experiments/results/lota_experiments.db')
    print(format_grounded_response(res))
    print('-' * 60)
